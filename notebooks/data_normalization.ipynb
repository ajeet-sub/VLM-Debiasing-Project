# %% [markdown]
# # Normalize

# %%
import numpy as np
import os
import pandas as pd

def normalize_based_on_split(df, output_dir, modalities, split_column='split', split="train"):
    """
    Normalizes the numpy arrays for each modality based on the train split, and saves them to the output directory.
    
    Args:
        df (pandas.DataFrame): DataFrame containing the metadata (paths and labels).
        input_dir (str): Directory containing the original numpy arrays.
        output_dir (str): Directory where normalized numpy arrays will be saved.
        modalities (list): List of column names for each modality.
        split_column (str): Column name that indicates the train/test split.
    """
    # Ensure output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Filter the rows that belong to the "train" split
    split_df = df[df[split_column] == split]
    
    # Normalize each modality separately based on the train split
    for modality in modalities:
        # Collect the paths of the modality files for the train split
        modality_paths = split_df[modality].values
        
        # Initialize lists to hold min and max values for normalization
        modality_data = []
        
        # Load the data for all train samples of this modality
        for path in modality_paths:
            data = np.load(path, allow_pickle=True)
            modality_data.append(data)
        
        # Convert to numpy array
        modality_data = np.array(modality_data)
        
        # Calculate min and max for normalization
        min_val = modality_data.min()
        max_val = modality_data.max()
        
        # Normalize each modality file in the train set based on the calculated min/max
        for i, path in enumerate(modality_paths):
            data = modality_data[i]
            # Normalize the data
            normalized_data = (data - min_val) / (max_val - min_val) if max_val > min_val else data
            # Save the normalized data back to the output directory
            output_path = os.path.join(output_dir, os.path.basename(path))
            np.save(output_path, normalized_data)
            print(f"Normalized and saved: {output_path}")

# %%
df = pd.read_csv("/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/audio_text_visual_paths.csv")
df.head()
# Out:
#    split  label  label.1  gender  \
# 0  train   22.0        0  female
# 1   test   23.0        0    male
# 2  train   19.0        0    male
# 3  train   67.0        1  female
# 4    dev   39.0        0    male
#
#                                                audio  \
# 0  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 1  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 2  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 3  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 4  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
#
#                                                 text  \
# 0  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 1  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 2  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 3  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 4  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
#
#                                               visual
# 0  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 1  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 2  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 3  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...
# 4  /home/hice1/mbibars3/scratch/vlm-debiasing/dat...

# %%
# Example usage
output_directory = '/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings'  # Path to save the normalized numpy arrays
modalities = ["text"]
normalize_based_on_split(df, output_directory, modalities, split="train")
# Out:
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/313_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/312_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/468_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/682_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/628_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/483_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/426_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/438_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/441_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/490_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/684_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/703_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/377_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/409_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/442_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/368_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/636_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/410_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/422_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/350_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/358_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/664_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/386_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/383_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/491_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/691_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/340_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/439_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/415_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/402_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/435_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/324_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/619_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/372_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/385_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/718_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/306_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/363_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/318_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/449_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/357_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/341_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/316_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/315_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/384_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/652_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/609_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/459_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/411_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/606_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/654_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/705_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/456_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/414_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/462_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/445_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/331_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/481_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/367_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/651_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/334_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/345_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/608_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/693_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/348_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/427_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/444_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/480_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/326_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/625_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/369_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/432_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/640_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/457_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/433_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/330_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/673_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/437_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/487_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/603_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/393_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/650_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/661_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/403_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/473_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/303_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/454_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/688_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/479_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/380_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/436_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/327_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/397_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/364_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/382_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/329_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/421_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/469_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/351_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/361_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/708_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/339_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/489_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/375_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/322_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/452_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/419_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/360_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/713_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/615_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/488_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/300_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/695_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/623_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/629_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/683_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/407_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/310_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/716_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/392_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/337_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/328_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/428_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/617_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/658_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/472_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/680_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/425_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/370_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/365_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/378_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/319_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/412_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/308_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/663_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/309_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/447_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/321_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/697_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/417_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/476_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/434_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/325_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/381_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/604_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/465_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/670_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/607_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/440_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/323_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/302_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/653_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/471_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/464_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/424_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/601_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/416_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/482_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/702_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/359_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/389_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/477_TEXT.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings/405_TEXT.npy

# %%
output_directory = '/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings'  # Path to save the normalized numpy arrays
modalities = ["audio"]
normalize_based_on_split(df, output_directory, modalities, split="dev")
# Out:
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/479_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/713_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/350_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/437_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/371_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/347_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/393_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/388_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/423_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/343_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/301_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/435_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/365_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/468_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/321_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/475_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/451_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/320_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/657_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/306_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/473_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/433_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/317_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/300_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/454_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/402_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/632_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/486_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/627_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/373_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/484_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/441_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/415_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/344_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/698_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/381_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/653_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/431_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/667_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/374_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/480_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/408_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/670_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/687_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/425_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/617_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/336_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/448_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/334_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/465_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/442_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/455_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/401_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/412_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/382_AUDIO.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/331_AUDIO.npy

# %%
output_directory = '/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings'  # Path to save the normalized numpy arrays
modalities = ["visual"]
normalize_based_on_split(df, output_directory, modalities, split="test")
# Out:
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/626_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/415_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/601_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/381_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/600_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/427_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/306_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/609_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/315_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/658_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/359_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/383_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/376_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/455_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/488_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/356_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/458_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/340_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/438_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/635_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/353_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/470_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/406_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/623_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/605_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/369_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/386_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/407_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/637_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/339_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/384_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/474_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/314_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/468_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/657_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/449_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/664_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/682_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/659_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/446_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/329_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/684_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/712_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/476_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/441_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/382_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/472_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/321_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/326_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/475_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/316_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/709_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/651_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/412_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/450_vis.npy
# Normalized and saved: /home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings/301_vis.npy

# %%
visual_dir = '/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_visual_embeddings'
vis_npy_files = glob.glob(f"{visual_dir}/*.npy")
print(len(vis_npy_files))
df["visual"] = vis_npy_files
# Out:
# 275

# %%
visual_dir = '/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings'
vis_npy_files = glob.glob(f"{visual_dir}/*.npy")
print(len(vis_npy_files))
df["audio"] = vis_npy_files
# Out:
# 275

# %%
visual_dir = '/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_TEXT_embeddings'
vis_npy_files = glob.glob(f"{visual_dir}/*.npy")
print(len(vis_npy_files))
df["text"] = vis_npy_files
# Out:
# 275

# %%
df["audio"][0]
# Out:
# '/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/normalized_audio_embeddings/432_AUDIO.npy'

# %%
df.to_csv("/home/hice1/mbibars3/scratch/vlm-debiasing/data/e-daic/norm_avt.csv", index=False)
